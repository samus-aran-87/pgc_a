# %%
import requests
import urllib.request
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
# https://www.whoishostingthis.com/tools/user-agent/

# %% [markdown]
# ### Pandas

# %%
table = pd.read_html('https://www.banki.ru/products/currency/cb/', encoding='UTF-8', header=0)
table = table[0]
table = table.loc[~table['Код'].isna()]
table.head()
# Out:
#    Код  Единиц                 Валюта  Курс ЦБ РФ Изменение
# 0  USD     1.0             Доллар США     67.5175   +1,3321
# 1  EUR     1.0                   Евро     75.8424   +2,1582
# 3  AUD     1.0   Австралийский доллар     44.8181   +0,9703
# 4  AZN     1.0  Азербайджанский манат     39.7981   +0,7852
# 5  AMD   100.0         Армянский драм     14.0955   +0,2781

# %% [markdown]
# ### BeautifulSoup #1

# %%
def get_html(url):
    result = requests.get(url)
    return result.text

def get_data(html):
    soup = BeautifulSoup(html, 'lxml')
    h1 = soup.find('h1', {'class':'page-header__info-title'})
    a = soup.find('a', {'href':'https://habr.com/ru/post/491622/'})
    navbar = soup.find('ul', {'id':'navbar-links'})
    li = navbar.find('li').find('a').text
    # print(soup)
    # print(type(soup))
    # print(h1.text)
    print(li)

def main():
    html = get_html('https://habr.com/ru/hub/python/')
    # print(html)
    get_data(html)

if __name__ == '__main__':
    main()
# Out:
# Все потоки

# %% [markdown]
# ### BeautifulSoup #2

# %%
def get_html(url):
    result = requests.get(url)
    return result.text

def get_data(html):
    soup = BeautifulSoup(html, 'lxml')
    # div = soup.find('div').get('id')
    # h1 = soup.find('h1').find('a').get('href')
    # h2 = soup.findAll('h2')
    # print(dir(h2))
    # for i in h2:
    #     print(i.text)
    section = soup.findAll('section', {'class':'plugin-section'})[1]
    plugins = section.findAll('article')
    # print(plugins)
    for i in plugins:
        h2 = i.find('h2')
        rating = i.find('span', {'class':'rating-count'})
        print('{} {}'.format(h2.text, rating.text))

def main():
    # html = get_html('https://ru.wordpress.org/')
    html = get_html('https://ru.wordpress.org/plugins/')
    # print(html)
    data = get_data(html)

if __name__ == '__main__':
    main()
# Out:
# Akismet Anti-Spam (857 total ratings)
# Classic Editor (785 total ratings)
# Jetpack от WordPress.com (1 464 total ratings)
# bbPress (303 total ratings)

# %% [markdown]
# ### urllib.request #1

# %%
sauce = urllib.request.urlopen('https://pythonprogramming.net/parsememcparseface/').read()
soup = BeautifulSoup(sauce, 'lxml')
table = soup.find('table')
table_rows = table.find_all('tr')

# %%
for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)
# Out:
# []
# ['Python', '932914021', 'Definitely']
# ['Pascal', '532', 'Unlikely']
# ['Lisp', '1522', 'Uncertain']
# ['D#', '12', 'Possibly']
# ['Cobol', '3', 'No.']
# ['Fortran', '52124', 'Yes.']
# ['Haskell', '24', 'lol.']

# %% [markdown]
# ### Pandas #2

# %%
dfs = pd.read_html('https://pythonprogramming.net/parsememcparseface/', header=0)

for df in dfs:
    print(df)

# dfs = dfs[0]
# dfs
# Out:
#   Program Name  Internet Points    Kittens?
# 0       Python        932914021  Definitely
# 1       Pascal              532    Unlikely
# 2         Lisp             1522   Uncertain
# 3           D#               12    Possibly
# 4        Cobol                3         No.
# 5      Fortran            52124        Yes.
# 6      Haskell               24        lol.

# %% [markdown]
# ### urllib.request #2

# %%
sauce = urllib.request.urlopen('https://pythonprogramming.net/sitemap.xml').read()
soup = BeautifulSoup(sauce, 'xml')

# %%
for url in soup.find_all('loc'):
    print(url.text)
# Out:
# https://pythonprogramming.net/downloads/intraQuarter.zip/
# https://pythonprogramming.net/downloads/knowledgeBase.db
# https://pythonprogramming.net/downloads/key_stats.csv
# https://pythonprogramming.net/downloads/style.zip
# https://pythonprogramming.net/community/post/
# https://pythonprogramming.net/about/privacy-policy/
# https://pythonprogramming.net/store/python-hoodie/
# https://pythonprogramming.net/about/super-powers/
# https://pythonprogramming.net/about/technology/
# https://pythonprogramming.net/about/tos/
# https://pythonprogramming.net/user/change-password/
# https://pythonprogramming.net/go/template-news-aggregator-go-language-programming-tutorial/
# https://pythonprogramming.net/go/looping-sitemap-data-go-language-programming-tutorial/
# https://pythonprogramming.net/go/channel-buffer-range-go-language-programming-tutorial/
# https://pythonprogramming.net/go/concurrency-web-app-go-language-programming-tutorial/
# ...

# %% [markdown]
# ### Beautiful Soup #3

# %%
sause = urllib.request.urlopen('https://pythonprogramming.net/parsememcparseface/').read()
soup = BeautifulSoup(sause, 'lxml')

# %%
# print(soup.find_all('p'))

for i in soup.find_all('p'):
    print(i.text)
    
# print(soup.get_text())

# for i in soup.find_all('a'):
#     print(i.get('href'))
# Out:
# Oh, hello! This is a wonderful page meant to let you practice web scraping. This page was originally created to help people work with the Beautiful Soup 4 library.
# The following table gives some general information for the following programming languages:
# I think it's clear that, on a scale of 1-10, python is:
# Javascript (dynamic data) test:
# y u bad tho?
# Whᶐt hαppéns now¿
# sitemap
# Contact: Harrison@pythonprogramming.net.
# Programming is a superpower.

# %% [markdown]
# ### requests

# %%
sause = requests.get('https://pythonprogramming.net/parsememcparseface/').text
soup = BeautifulSoup(sause, 'lxml')

# %%
for i in soup.find_all('p'):
    print(i.text)
    
# print(soup.get_text())
# Out:
# Oh, hello! This is a wonderful page meant to let you practice web scraping. This page was originally created to help people work with the Beautiful Soup 4 library.
# The following table gives some general information for the following programming languages:
# I think it's clear that, on a scale of 1-10, python is:
# Javascript (dynamic data) test:
# y u bad tho?
# Whᶐt hαppéns now¿
# sitemap
# Contact: Harrison@pythonprogramming.net.
# Programming is a superpower.

# %%
# for url in soup.find_all('a'):
#     print(url)

# %%
nav = soup.nav

# %%
for url in nav.find_all('a'):
    print(url.get('href'))
# Out:
# /
# #
# /
# /+=1/
# /support/
# https://goo.gl/7zgAVQ
# /login/
# /register/
# /
# /+=1/
# /support/
# https://goo.gl/7zgAVQ
# /login/
# /register/

# %%
body = soup.body

# %%
for p in body.find_all('p'):
    print(p.text)
# Out:
# Oh, hello! This is a wonderful page meant to let you practice web scraping. This page was originally created to help people work with the Beautiful Soup 4 library.
# The following table gives some general information for the following programming languages:
# I think it's clear that, on a scale of 1-10, python is:
# Javascript (dynamic data) test:
# y u bad tho?
# Whᶐt hαppéns now¿
# sitemap

# %%
# for div in soup.find_all('div', class_='body'):
# # for div in soup.find_all('div', {'class':'body'}):
#     print(div.text)

# %% [markdown]
# ### urllib.request #3

# %%
sause = urllib.request.urlopen('https://pythonprogramming.net/parsememcparseface/')
soup = BeautifulSoup(sause, 'lxml')
js_test = soup.find('p', {'class':'jstest'})
print(js_test.text)
# Out:
# y u bad tho?

# %%
# from PyQt5.QtWebKit import QWebPage
# from PyQt5.QtWebKitWidgets import QWebPage
# from PyQt5.QtWebKit import QWebSettings

# from PyQt5.QtWidgets import QApplication
# from PyQt5.QtCore import QUrl
# import sys

# from PyQt5.QtWebEngineWidgets import QWebEngineView as QWebView, QWebEnginePage as QWebPage
# from PyQt5.QtWebEngineWidgets import QWebEngineSettings as QWebSettings

# %%
import bs4 as bs
import sys
import urllib.request
from PyQt5.QtWebEngineWidgets import QWebEnginePage
from PyQt5.QtWidgets import QApplication
from PyQt5.QtCore import QUrl

class Page(QWebEnginePage):
    def __init__(self, url):
        self.app = QApplication(sys.argv)
        QWebEnginePage.__init__(self)
        self.html = ''
        self.loadFinished.connect(self._on_load_finished)
        self.load(QUrl(url))
        self.app.exec_()

    def _on_load_finished(self):
        self.html = self.toHtml(self.Callable)
        print('Load finished')

    def Callable(self, html_str):
        self.html = html_str
        self.app.quit()


def main():
    page = Page('https://pythonprogramming.net/parsememcparseface/')
    soup = bs.BeautifulSoup(page.html, 'html.parser')
    js_test = soup.find('p', class_='jstest')
    print(js_test.text)

if __name__ == '__main__': main()
# Out:
# Load finished
# Look at you shinin!

# %%
table = pd.read_html('http://www.finmarket.ru/currency/rates/', header=0)
data = table[1]
data
# Out:
#     Код                     Валюта  Кол-во     Курс Изменение
# 0   AUD       Австралийский доллар       1   472817   +2,4636
# 1   AZN      Азербайджанский манат       1   424526   +2,6545
# 2   AMD             Армянский драм     100   150435   +0,9480
# 3   BYN          Белорусский рубль       1   310877   +0,9285
# 4   BGN             Болгарский лев       1   419335   +3,0924
# 5   BRL           Бразильский реал       1   152438   +0,5903
# 6   HUF          Венгерский форинт     100   243932   +1,8246
# 7   KRW      Вона Республики Корея   1 000   602922   +3,4028
# 8   HKD         Гонконгский доллар      10   927076   +5,8360
# 9   DKK              Датская крона       1   109803   +0,8094
# 10  USD                 Доллар США       1   720208   +4,5033
# 11  EUR                       ЕВРО       1   818588   +6,0164
# 12  INR            Индийская рупия     100   971292   +5,3249
# 13  KZT        Казахстанский тенге     100   181834   +0,5352
# ...
